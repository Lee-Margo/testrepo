# %% [markdown]
# ## Python

# %%
pwd
# Out:
# 'C:\\Users\\margo\\AI Course'

# %%
2+9-3*5/3
# Out:
# 6.0

# %%
4**2
# Out:
# 16

# %%
100/3
# Out:
# 33.333333333333336

# %%
100//3 #floor division
# Out:
# 33

# %%
input()
# Out:
# 100
# '100'

# %% [markdown]
# # Hello
# ###### Hello
# * Hello

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
5-9
# Out:
# -4

# %%
5%3 #modulo
# Out:
# 2

# %% [markdown]
# ### A or B for new cell

# %%
# M for markdown 
# Y for coding

# %% [markdown]
# # Head
# * pt
#     * pt
#         * pt
#             * pt
#                 * pt
#
# ## Sub Head
# 1. Hello
# 2. Hi
#     1. Hello
#     2. Hi
#         1. Hello
#         2. Hi
#             1. Hello
#             2. Hi

# %% [markdown]
# # Python
# ![image.png](attachment:image.png)
#
# ### Python today
#
# 1. Head and sub head
# 2. floor division
# 3. insert image under markdown

# %% [markdown]
# ### Types of values
# ###### Int 2,3,45
# ###### Float 3.4 , 4.5, 6.7
# ###### str " ",' ',''' ''', "TEXT"
# ###### Bool TRUE OR FALSE
# * T =x= t  python is case sensitive
# * read top to bottom
# * left to right

# %%
type("a")
# Out:
# str

# %%
print(123)
23
24
25
# Out:
# 123
# 25
